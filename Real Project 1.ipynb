# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\ASUS\Desktop\New folder\weather.csv')

# %%
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %% [markdown]
# # How to analyze DataFrames?

# %%
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
#        'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time              object
# Temp (C)              float64
# Dew Point Temp (C)    float64
# Rel Hum (%)             int64
# Wind Spd (km/h)         int64
# Visibility (km)       float64
# Stn Press (kPa)       float64
# Weather                object
# dtype: object

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.nunique()
# Out:
# Date/Time             8784
# Temp (C)               533
# Dew Point Temp (C)     489
# Rel Hum (%)             83
# Wind Spd (km/h)         34
# Visibility (km)         24
# Stn Press (kPa)        518
# Weather                 50
# dtype: int64

# %%
df.count()
# Out:
# Date/Time             8784
# Temp (C)              8784
# Dew Point Temp (C)    8784
# Rel Hum (%)           8784
# Wind Spd (km/h)       8784
# Visibility (km)       8784
# Stn Press (kPa)       8784
# Weather               8784
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date/Time           8784 non-null   object
#  1   Temp (C)            8784 non-null   float64
#  2   Dew Point Temp (C)  8784 non-null   float64
#  3   Rel Hum (%)         8784 non-null   int64
#  4   Wind Spd (km/h)     8784 non-null   int64
#  5   Visibility (km)     8784 non-null   float64
#  6   Stn Press (kPa)     8784 non-null   float64
#  7   Weather             8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# # Q1. Find all the unique 'Wind Spped' values in the data.

# %%
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %%
df['Wind Spd (km/h)'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
df['Wind Spd (km/h)'].nunique()
# Out:
# 34

# %% [markdown]
# # Q2.Find the number of times when the 'Weather is exactly clear'.

# %%
df.Weather.value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df[df.Weather == 'Clear']
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 67    2012-01-03 19:00:00     -16.9               -24.8           50
# 114   2012-01-05 18:00:00      -7.1               -14.4           56
# 115   2012-01-05 19:00:00      -9.2               -15.4           61
# 116   2012-01-05 20:00:00      -9.8               -15.7           62
# 117   2012-01-05 21:00:00      -9.0               -14.8           63
# ...                   ...       ...                 ...          ...
# 8646  2012-12-26 06:00:00     -13.4               -14.8           89
# 8698  2012-12-28 10:00:00      -6.1                -8.6           82
# 8713  2012-12-29 01:00:00     -11.9               -13.6           87
# 8714  2012-12-29 02:00:00     -11.8               -13.1           90
# 8756  2012-12-30 20:00:00     -13.8               -16.5           80
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 67                 24             25.0           101.74   Clear
# ...

# %%
df.groupby('Weather').get_group('Clear')
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 67    2012-01-03 19:00:00     -16.9               -24.8           50
# 114   2012-01-05 18:00:00      -7.1               -14.4           56
# 115   2012-01-05 19:00:00      -9.2               -15.4           61
# 116   2012-01-05 20:00:00      -9.8               -15.7           62
# 117   2012-01-05 21:00:00      -9.0               -14.8           63
# ...                   ...       ...                 ...          ...
# 8646  2012-12-26 06:00:00     -13.4               -14.8           89
# 8698  2012-12-28 10:00:00      -6.1                -8.6           82
# 8713  2012-12-29 01:00:00     -11.9               -13.6           87
# 8714  2012-12-29 02:00:00     -11.8               -13.1           90
# 8756  2012-12-30 20:00:00     -13.8               -16.5           80
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 67                 24             25.0           101.74   Clear
# ...

# %% [markdown]
# # Q3.Find the number of times when the 'Wind Speed is exactly 4km/hr'.

# %%
df.groupby('Wind Spd (km/h)').get_group(4)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 96    2012-01-05 00:00:00      -8.8               -11.7           79
# 101   2012-01-05 05:00:00      -7.0                -9.5           82
# 146   2012-01-07 02:00:00      -8.1               -11.1           79
# ...                   ...       ...                 ...          ...
# 8768  2012-12-31 08:00:00      -8.6               -10.3           87
# 8769  2012-12-31 09:00:00      -8.1                -9.6           89
# 8770  2012-12-31 10:00:00      -7.4                -8.9           89
# 8772  2012-12-31 12:00:00      -5.8                -7.5           88
# 8773  2012-12-31 13:00:00      -4.6                -6.6           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# ...

# %%
df[df['Wind Spd (km/h)']== 4]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 96    2012-01-05 00:00:00      -8.8               -11.7           79
# 101   2012-01-05 05:00:00      -7.0                -9.5           82
# 146   2012-01-07 02:00:00      -8.1               -11.1           79
# ...                   ...       ...                 ...          ...
# 8768  2012-12-31 08:00:00      -8.6               -10.3           87
# 8769  2012-12-31 09:00:00      -8.1                -9.6           89
# 8770  2012-12-31 10:00:00      -7.4                -8.9           89
# 8772  2012-12-31 12:00:00      -5.8                -7.5           88
# 8773  2012-12-31 13:00:00      -4.6                -6.6           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# ...

# %% [markdown]
# # Q4. Find out all the null values in the data.

# %%
df.isnull().sum()
# Out:
# Date/Time             0
# Temp (C)              0
# Dew Point Temp (C)    0
# Rel Hum (%)           0
# Wind Spd (km/h)       0
# Visibility (km)       0
# Stn Press (kPa)       0
# Weather               0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Date/Time             8784
# Temp (C)              8784
# Dew Point Temp (C)    8784
# Rel Hum (%)           8784
# Wind Spd (km/h)       8784
# Visibility (km)       8784
# Stn Press (kPa)       8784
# Weather               8784
# dtype: int64

# %% [markdown]
# # Q5. Rename  the column name 'Weather' of the dataframe to 'Weather Conditions'.

# %%
df.rename(columns = {'Weather': 'Weather Columns'}, inplace = True)

# %%
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather Columns
# ...

# %% [markdown]
# # Q6. What is the mean 'Visibility'?

# %%
df.rename(columns = {'Visibility (km)': 'Visibility_km'}, inplace = True)

# %%
df.Visibility_km.mean()
# Out:
# 27.664446721311478

# %% [markdown]
# # Q7. What is the standard deviation of 'Pressure' in this data.

# %%
df.head(2)
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
#
#    Wind Spd (km/h)  Visibility_km  Stn Press (kPa) Weather Columns
# 0                4            8.0           101.24             Fog
# 1                4            8.0           101.24             Fog

# %%
df.rename(columns = {'Stn Press (kPa)': 'Stn_Press_(kPa)'}, inplace = True)

# %%
df['Stn_Press_(kPa)'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# # Q8. What is the Variance of 'Relative Humdiity' in the data.

# %%
df['Rel Hum (%)'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# # Q9. Find all the instances when 'Snow' was recorded.

# %%
df[df['Weather Columns']=='Snow']
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 55    2012-01-03 07:00:00     -14.0               -19.5           63
# 84    2012-01-04 12:00:00     -13.7               -21.7           51
# 86    2012-01-04 14:00:00     -11.3               -19.0           53
# 87    2012-01-04 15:00:00     -10.2               -16.3           61
# 88    2012-01-04 16:00:00      -9.4               -15.5           61
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility_km  Stn_Press_(kPa) Weather Columns
# ...

# %%
df['Weather Columns'].value_counts()
# Out:
# Weather Columns
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# # Q10. Find all instances where 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
df[(df['Wind Spd (km/h)'] > 24) & (df['Visibility_km'] == 25)]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 23    2012-01-01 23:00:00       5.3                 2.0           79
# 24    2012-01-02 00:00:00       5.2                 1.5           77
# 25    2012-01-02 01:00:00       4.6                 0.0           72
# 26    2012-01-02 02:00:00       3.9                -0.9           71
# 27    2012-01-02 03:00:00       3.7                -1.5           69
# ...                   ...       ...                 ...          ...
# 8705  2012-12-28 17:00:00      -8.6               -12.0           76
# 8753  2012-12-30 17:00:00     -12.1               -15.8           74
# 8755  2012-12-30 19:00:00     -13.4               -16.5           77
# 8759  2012-12-30 23:00:00     -12.1               -15.1           78
# 8760  2012-12-31 00:00:00     -11.1               -14.4           77
#
#       Wind Spd (km/h)  Visibility_km  Stn_Press_(kPa) Weather Columns
# ...

# %% [markdown]
# # Q11. What is the mean value of each column against each 'Weather Condition'?

# %%
df.head(2)
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
#
#    Wind Spd (km/h)  Visibility_km  Stn_Press_(kPa) Weather Columns
# 0                4            8.0           101.24             Fog
# 1                4            8.0           101.24             Fog

# %%
df['Weather Columns'].astype(str)
# Out:
# 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather Columns, Length: 8784, dtype: object

# %%
df.groupby('Weather Columns').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %% [markdown]
# # Q.11 What is the minimum and maximum value of each column against each weather condition?

# %%
df.groupby('Weather Columns').min()
# Out:
#                                                    Date/Time  Temp (C)  \
# Weather Columns
# Clear                                    2012-01-03 19:00:00     -23.3
# Cloudy                                   2012-01-01 17:00:00     -21.4
# Drizzle                                  2012-01-23 21:00:00       1.1
# Drizzle,Fog                              2012-01-23 20:00:00       0.0
# Drizzle,Ice Pellets,Fog                  2012-12-17 09:00:00       0.4
# Drizzle,Snow                             2012-12-17 15:00:00       0.9
# Drizzle,Snow,Fog                         2012-12-18 21:00:00       0.3
# Fog                                      2012-01-01 00:00:00     -16.0
# Freezing Drizzle                         2012-01-07 11:00:00      -9.0
# Freezing Drizzle,Fog                     2012-01-01 02:00:00      -6.4
# Freezing Drizzle,Haze                    2012-02-01 11:00:00      -5.8
# Freezing Drizzle,Snow                    2012-01-13 03:00:00      -8.3
# ...

# %%
df.groupby('Weather Columns').max()
# Out:
#                                                    Date/Time  Temp (C)  \
# Weather Columns
# Clear                                    2012-12-30 20:00:00      32.8
# Cloudy                                   2012-12-31 06:00:00      30.5
# Drizzle                                  2012-12-22 01:00:00      18.8
# Drizzle,Fog                              2012-12-19 10:00:00      19.9
# Drizzle,Ice Pellets,Fog                  2012-12-17 09:00:00       0.4
# Drizzle,Snow                             2012-12-19 18:00:00       1.2
# Drizzle,Snow,Fog                         2012-12-22 03:00:00       1.1
# Fog                                      2012-12-29 10:00:00      20.8
# Freezing Drizzle                         2012-12-17 00:00:00      -2.3
# Freezing Drizzle,Fog                     2012-12-10 05:00:00      -0.3
# Freezing Drizzle,Haze                    2012-02-01 13:00:00      -5.0
# Freezing Drizzle,Snow                    2012-12-28 02:00:00      -3.3
# ...

# %% [markdown]
# # Q13. Show all records where Weather Condition is Fog.

# %%
df[df['Weather Columns'] == 'Fog']
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# 5     2012-01-01 05:00:00      -1.4                -3.3           87
# 6     2012-01-01 06:00:00      -1.5                -3.1           89
# ...                   ...       ...                 ...          ...
# 8716  2012-12-29 04:00:00     -16.0               -17.2           90
# 8717  2012-12-29 05:00:00     -14.8               -15.9           91
# 8718  2012-12-29 06:00:00     -13.8               -15.3           88
# 8719  2012-12-29 07:00:00     -14.8               -16.4           88
# 8722  2012-12-29 10:00:00     -12.0               -13.3           90
#
#       Wind Spd (km/h)  Visibility_km  Stn_Press_(kPa) Weather Columns
# ...

# %% [markdown]
# # Q14. Find all instances when 'Weather is Clear' or 'Visibility is 40'.

# %%
df.head(2)
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
#
#    Wind Spd (km/h)  Visibility_km  Stn_Press_(kPa) Weather Columns
# 0                4            8.0           101.24             Fog
# 1                4            8.0           101.24             Fog

# %%
df[(df['Weather Columns'] == 'Clear') | (df['Visibility_km'] > 40)]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 67    2012-01-03 19:00:00     -16.9               -24.8           50
# 106   2012-01-05 10:00:00      -6.0               -10.0           73
# 107   2012-01-05 11:00:00      -5.6               -10.2           70
# 108   2012-01-05 12:00:00      -4.7                -9.6           69
# 109   2012-01-05 13:00:00      -4.4                -9.7           66
# ...                   ...       ...                 ...          ...
# 8749  2012-12-30 13:00:00     -12.4               -16.2           73
# 8750  2012-12-30 14:00:00     -11.8               -16.1           70
# 8751  2012-12-30 15:00:00     -11.3               -15.6           70
# 8752  2012-12-30 16:00:00     -11.4               -15.5           72
# 8756  2012-12-30 20:00:00     -13.8               -16.5           80
#
#       Wind Spd (km/h)  Visibility_km  Stn_Press_(kPa) Weather Columns
# ...

# %% [markdown]
# <!-- Q15. Find all instances when:
#     A. 'Weather is Clear' and 'Relative Humidity is greater 50'
#     OR
#     B. Visibility is above 40  -->

# %% [markdown]
# # # Q15. Find all instances when:
# #     A. 'Weather is Clear' and 'Relative Humidity is greater 50'
# #     OR
# # #     B. Visibility is above 40

# %%
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility_km  Stn_Press_(kPa)       Weather Columns
# 0                4            8.0           101.24                   Fog
# 1                4            8.0           101.24                   Fog
# 2                7            4.0           101.26  Freezing Drizzle,Fog
# 3                6            4.0           101.27  Freezing Drizzle,Fog
# 4                7            4.8           101.23                   Fog

# %%
df[((df['Weather Columns'] == 'Clear') & (df['Rel Hum (%)'] > 50)) | (df['Visibility_km'] > 40)].head(50)
# Out:
#                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 106  2012-01-05 10:00:00      -6.0               -10.0           73
# 107  2012-01-05 11:00:00      -5.6               -10.2           70
# 108  2012-01-05 12:00:00      -4.7                -9.6           69
# 109  2012-01-05 13:00:00      -4.4                -9.7           66
# 110  2012-01-05 14:00:00      -5.1               -10.7           65
# 111  2012-01-05 15:00:00      -4.3               -12.0           55
# 114  2012-01-05 18:00:00      -7.1               -14.4           56
# 115  2012-01-05 19:00:00      -9.2               -15.4           61
# 116  2012-01-05 20:00:00      -9.8               -15.7           62
# 117  2012-01-05 21:00:00      -9.0               -14.8           63
# 183  2012-01-08 15:00:00      -6.6               -12.9           61
# 241  2012-01-11 01:00:00     -10.7               -17.8           56
# 242  2012-01-11 02:00:00     -12.0               -18.9           56
# ...
